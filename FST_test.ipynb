# %%
import fst
A = fst.linear_chain('fst')
A
# Out:
# <StdVectorFst with 4 states>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(range(10),range(10))
plt.show()

# %%
t = fst.Transducer()

t.add_arc(0, 1, 'a', 'A')
t.add_arc(0, 1, 'b', 'B')
t.add_arc(1, 2, 'c', 'C')

t[2].final = True
t
# Out:
# <StdVectorFst with 3 states>

# %%
a = fst.Acceptor()
a.add_arc(0, 1, 'x', 0.1)
a[1].final = -1
a[1].final
# Out:
# TropicalWeight(-1.0)

# %%
import fst
from LTL.buchi import buchi_from_ltl
import networkx as nx
import matplotlib.pyplot as plt

G = buchi_from_ltl("([]<>a) && ([]<> b)","office")


T = fst.Acceptor()
for (u,v,d) in G.edges(data=True):
    T.add_arc(u,v,d['guard'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-13753184cf9a> in <module>()
#       9 T = fst.Acceptor()
#      10 for (u,v) in G.edges():
# ---> 11     T.add_arc(u,v)
#
# TypeError: add_arc() takes at least 4 arguments (3 given)
